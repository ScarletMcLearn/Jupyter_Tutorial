# %% [markdown]
# # Jupyter Tutorial
#
# This is a Jupyter tutorial

# %% [markdown]
# <img src="http://blog.jupyter.org/content/images/2015/02/jupyter-sq-text.png"
# style="width:100px;height:100px;float:left">

# %%
1+2
# Out:
# 3

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
a=1
b=2
a+b;

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.arange(20)
y = x**2

plt.plot(x, y)

# %% [markdown]
# Latex can also be used in Jupyter to write math expression

# %% [markdown]
# $$\int_0^{+\infty} x^2 dx$$

# %% [markdown]
# some inline expression, for example, $\int^2_1 x^2 dx$

# %% [markdown]
# Table can also be drawn in Jupyter
#
# |Item       |Value |Qty|
# |:-------|------:|:---:|
# |Computer|1600 USD|5  |
# |Phone|12 USD|12 |
# |Cable|1 USD|23 |

# %%
from IPython.display import Image
Image(filename="Background.jpg")

# %%
from IPython.display import HTML
site='''<iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allowfullscreen></iframe>'''
video=HTML(site)
video
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# Website can be inserted into Jupyter

# %%
from IPython.display import IFrame
IFrame('http://jupyter.org',width='100%',height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="http://jupyter.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import FileLink,FileLinks
FileLink('./Background.jpg')
# Out:
# /home/wjh/Untitled Folder/Background.jpg

# %%
# %%writefile test.py
import datetime

def print_time():
    print 'the time is:'
    return datetime.datetime.now()
# Out:
# Overwriting test.py

# %%
# %pycat test.py

# %%
# %load test.py
import datetime

def print_time():
    print 'the time is:'
    return datetime.datetime.now()

# %%
# %run test.py
print_time()
# Out:
# the time is:
# datetime.datetime(2017, 2, 2, 16, 10, 53, 428120)

# %%
# %%timeit -n 100 -r 5
sum=0
for i in range(100):
    sum+=i
print sum
# Out:
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# 4950
# ...

# %% [markdown]
# Jupyter can be just like a terminal

# %%
pwd
# Out:
# u'/home/wjh/Untitled Folder'

# %%
ls
# Out:
# Background.jpg         Jupyter_tutorial.ipynb  Jupyter_tutorial.py
# Jupyter_tutorial.html  Jupyter_tutorial.pdf    test.py

# %%
# %%bash
# echo "Hello"
# Out:
# Hello
